# %% [markdown]
# # #04: Pemilihan kolom (columns selection) pada Data Frame berdasarkan tipe data
# ## Import Modules

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.0.3
# 1.24.3

# %% [markdown]
# ## Persiapan Data Frame

# %%
n_rows = 5
n_cols = 2
cols = ['bil_pecahan', 'bil_bulat']

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), 
                  columns=cols)

df['bil_pecahan'] = df['bil_pecahan'].astype('float')

df
# Out:
#    bil_pecahan  bil_bulat
# 0          7.0         14
# 1         11.0         14
# 2         19.0          7
# 3         10.0          7
# 4         17.0          6

# %%
# df.index = pd.util.testing.makeDateIndex(n_rows, freq='H')
df.index = pd.date_range(start='2023-10-01', periods=n_rows, freq='H')

df = df.reset_index()

df['teks'] = list('ABCDE')

df
# Out:
#                 index  bil_pecahan  bil_bulat teks
# 0 2023-10-01 00:00:00          7.0         14    A
# 1 2023-10-01 01:00:00         11.0         14    B
# 2 2023-10-01 02:00:00         19.0          7    C
# 3 2023-10-01 03:00:00         10.0          7    D
# 4 2023-10-01 04:00:00         17.0          6    E

# %%
df.dtypes
# Out:
# index          datetime64[ns]
# bil_pecahan           float64
# bil_bulat               int64
# teks                   object
# dtype: object

# %% [markdown]
# ## Memilih kolom bertipe data numerik

# %%
df.select_dtypes(include='number')
# Out:
#    bil_pecahan  bil_bulat
# 0          7.0         14
# 1         11.0         14
# 2         19.0          7
# 3         10.0          7
# 4         17.0          6

# %%
df.select_dtypes(include='float')
# Out:
#    bil_pecahan
# 0          7.0
# 1         11.0
# 2         19.0
# 3         10.0
# 4         17.0

# %%
df.select_dtypes(include='int')
# Out:
#    bil_bulat
# 0         14
# 1         14
# 2          7
# 3          7
# 4          6

# %% [markdown]
# ## Memilih kolom bertipe data string atau `object`

# %%
df.select_dtypes(include='object')
# Out:
#   teks
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E

# %% [markdown]
# ## Memilih kolom bertipe data `datetime`

# %%
df.select_dtypes(include='datetime')
# Out:
#                 index
# 0 2023-10-01 00:00:00
# 1 2023-10-01 01:00:00
# 2 2023-10-01 02:00:00
# 3 2023-10-01 03:00:00
# 4 2023-10-01 04:00:00

# %% [markdown]
# ## Memilih kolom dengan kombinasi tipe data

# %%
df.select_dtypes(include=['number', 'object'])
# Out:
#    bil_pecahan  bil_bulat teks
# 0          7.0         14    A
# 1         11.0         14    B
# 2         19.0          7    C
# 3         10.0          7    D
# 4         17.0          6    E
