# %% [markdown]
# # #07: Menghapus (drop) missing values `(NaN)`
# ## Import Modules

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.0.3
# 1.24.3

# %% [markdown]
# ## Persiapan Data Frame

# %%
## DEPRICATED ##
# df = pd.util.testing.makeMissingDataframe().reset_index() 
# df.head()

# %%
n_rows = 30
n_cols = 4
cols = ['A', 'B', 'C', 'D']

df = pd.DataFrame(np.random.randn(n_rows, n_cols), columns=cols)

nan_mask = np.random.rand(n_rows, n_cols) < 0.2
df[nan_mask] = np.nan

df = df.reset_index()
df.head()
# Out:
#    index         A         B         C         D
# 0      0  0.516076  0.079116 -0.202817  1.058222
# 1      1       NaN -0.721026 -0.111947 -1.342626
# 2      2       NaN  0.349353 -1.664095 -0.019539
# 3      3 -0.254767  0.830741 -1.264514 -1.352101
# 4      4  0.755976  1.209761  1.332054       NaN

# %%
df = df.rename(columns={'index':'Z'})
df.head()
# Out:
#    Z         A         B         C         D
# 0  0  0.516076  0.079116 -0.202817  1.058222
# 1  1       NaN -0.721026 -0.111947 -1.342626
# 2  2       NaN  0.349353 -1.664095 -0.019539
# 3  3 -0.254767  0.830741 -1.264514 -1.352101
# 4  4  0.755976  1.209761  1.332054       NaN

# %%
df_backup = df.copy(deep=True)

# %% [markdown]
# ## Menghapus (drop) setiap kolom yang mengandung missing values

# %%
df = df.dropna(axis='columns') 
df.head()
# Out:
#    Z
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4

# %% [markdown]
# ## Menghapus (drop) setiap baris yang mengandung missing values

# %%
df = df_backup.copy(deep=True)
df = df.dropna(axis='rows')
df.head()
# Out:
#      Z         A         B         C         D
# 0    0  0.516076  0.079116 -0.202817  1.058222
# 3    3 -0.254767  0.830741 -1.264514 -1.352101
# 9    9  0.129913 -0.310577  0.598951 -0.608485
# 11  11 -0.438096  0.541933 -0.274625  0.887635
# 12  12  0.403773 -2.308836  0.272621 -0.554832

# %% [markdown]
# ## Persentase missing values untuk tiap kolom

# %%
df = df_backup.copy(deep=True)
df.isna().mean()
# Out:
# Z    0.000000
# A    0.166667
# B    0.166667
# C    0.100000
# D    0.200000
# dtype: float64

# %% [markdown]
# ## Menghapus (drop) setiap kolom yang mengandung missing values berdasarkan threshold

# %%
treshold = len(df) * 0.9
df = df.dropna(thresh=treshold, axis='columns')
df.head()
# Out:
#    Z         C
# 0  0 -0.202817
# 1  1 -0.111947
# 2  2 -1.664095
# 3  3 -1.264514
# 4  4  1.332054
